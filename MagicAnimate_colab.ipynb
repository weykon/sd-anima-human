# %% [markdown]
# <a href="https://colab.research.google.com/github/weykon/sd-anima-human/blob/main/MagicAnimate_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MagicAnimate-hf

# !pip install -q diffusers==0.21.4 transformers==4.32.0 accelerate==0.22.0 omegaconf==2.3.0 einops==0.6.1 av gradio
# !pip install -q https://download.pytorch.org/whl/cu118/xformers-0.0.22.post4%2Bcu118-cp310-cp310-manylinux2014_x86_64.whl

# !apt -y install -qq aria2
BaseModelUrl = "https://huggingface.co/runwayml/stable-diffusion-v1-5"
BaseModelDir = "/content/MagicAnimate-hf/stable-diffusion-v1-5"
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/model_index.json -d {BaseModelDir} -o model_index.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/vae/diffusion_pytorch_model.bin -d {BaseModelDir}/vae -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/vae/config.json -d {BaseModelDir}/vae -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/unet/diffusion_pytorch_model.bin -d {BaseModelDir}/unet -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/unet/config.json -d {BaseModelDir}/unet -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/vocab.json -d {BaseModelDir}/tokenizer -o vocab.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/tokenizer_config.json -d {BaseModelDir}/tokenizer -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/special_tokens_map.json -d {BaseModelDir}/tokenizer -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/tokenizer/merges.txt -d {BaseModelDir}/tokenizer -o merges.txt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/text_encoder/pytorch_model.bin -d {BaseModelDir}/text_encoder -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/text_encoder/config.json -d {BaseModelDir}/text_encoder -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/scheduler/scheduler_config.json -d {BaseModelDir}/scheduler -o scheduler_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/resolve/main/safety_checker/pytorch_model.bin -d {BaseModelDir}/safety_checker -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/safety_checker/config.json -d {BaseModelDir}/safety_checker -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {BaseModelUrl}/raw/main/feature_extractor/preprocessor_config.json -d {BaseModelDir}/feature_extractor -o preprocessor_config.json

# %cd /content/MagicAnimate-hf
# !python app.py
# Out:
# /content
# Cloning into 'MagicAnimate-hf'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 142 (delta 34), reused 141 (delta 33), pack-reused 0
# Receiving objects: 100% (142/142), 5.50 MiB | 4.19 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 40.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 33.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 35.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 17.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 40.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.3 MB/s eta 0:00:00
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 MB 4.0 MB/s eta 0:00:00
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 15 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120882 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c242e2|OK  |    75KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/model_index.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4751b9|OK  |   283MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/vae/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f6f64c|OK  |    76KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/vae/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 66f4d2|OK  |   198MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/unet/diffusion_pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 573d62|OK  |   120KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/unet/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ddbcfe|OK  |   3.0MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/vocab.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3cb537|OK  |   131KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/tokenizer_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ba315f|OK  |    65KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/special_tokens_map.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3c9fe1|OK  |   3.0MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/tokenizer/merges.txt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 53a89a|OK  |   287MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/text_encoder/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# cf8aa9|OK  |    86KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/text_encoder/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 87e870|OK  |    42KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/scheduler/scheduler_config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5927dc|OK  |   256MiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/safety_checker/pytorch_model.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# abd3f0|OK  |   768KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/safety_checker/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 320ecd|OK  |    47KiB/s|/content/MagicAnimate-hf/stable-diffusion-v1-5/feature_extractor/preprocessor_config.json
#
# Status Legend:
# (OK):download completed.
# /content/MagicAnimate-hf
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2023-12-05 15:42:42.789396: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-05 15:42:42.789456: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-05 15:42:42.789501: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-05 15:42:43.935105: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# .gitattributes: 100% 1.46k/1.46k [00:00<00:00, 5.44MB/s]
# Fetching 5 files:  20% 1/5 [00:00<00:03,  1.11it/s]
# README.md: 100% 6.84k/6.84k [00:00<00:00, 27.7MB/s]
#
# config.json: 100% 547/547 [00:00<00:00, 2.30MB/s]
# Fetching 5 files:  60% 3/5 [00:01<00:00,  3.49it/s]
# diffusion_pytorch_model.bin:   0% 0.00/335M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   6% 21.0M/335M [00:00<00:02, 125MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:  13% 41.9M/335M [00:00<00:01, 150MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:04, 69.3MB/s]
# diffusion_pytorch_model.bin:  22% 73.4M/335M [00:00<00:01, 179MB/s]
# diffusion_pytorch_model.bin:  28% 94.4M/335M [00:00<00:01, 180MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:02, 107MB/s]
# diffusion_pytorch_model.bin:  34% 115M/335M [00:00<00:01, 157MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:02, 111MB/s]
# diffusion_pytorch_model.bin:  41% 136M/335M [00:00<00:01, 138MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:00<00:02, 111MB/s]
# diffusion_pytorch_model.bin:  47% 157M/335M [00:01<00:01, 132MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:00<00:02, 113MB/s]
# diffusion_pytorch_model.bin:  53% 178M/335M [00:01<00:01, 133MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 115M/335M [00:01<00:01, 111MB/s]
# diffusion_pytorch_model.bin:  60% 199M/335M [00:01<00:00, 140MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:01, 117MB/s]
# diffusion_pytorch_model.bin:  66% 220M/335M [00:01<00:00, 139MB/s]
# diffusion_pytorch_model.bin:  72% 241M/335M [00:01<00:00, 141MB/s]
#
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 112MB/s]
# diffusion_pytorch_model.bin:  78% 262M/335M [00:01<00:00, 139MB/s]
#
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:01<00:01, 108MB/s]
# diffusion_pytorch_model.bin:  85% 283M/335M [00:01<00:00, 139MB/s]
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:01<00:01, 112MB/s]
# diffusion_pytorch_model.bin:  91% 304M/335M [00:02<00:00, 134MB/s]
#
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:01<00:00, 127MB/s]
# diffusion_pytorch_model.bin:  97% 325M/335M [00:02<00:00, 143MB/s]
#
# diffusion_pytorch_model.bin: 100% 335M/335M [00:02<00:00, 141MB/s]
# Fetching 5 files:  80% 4/5 [00:03<00:01,  1.01s/it]
#
# diffusion_pytorch_model.safetensors:  78% 262M/335M [00:02<00:00, 144MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:02<00:00, 175MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 135MB/s]
# Fetching 5 files: 100% 5/5 [00:03<00:00,  1.32it/s]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 6.46MB/s]
# Fetching 7 files:  14% 1/7 [00:00<00:01,  5.28it/s]
# README.md: 100% 139/139 [00:00<00:00, 659kB/s]
#
# densepose_controlnet/config.json: 100% 1.33k/1.33k [00:00<00:00, 9.08MB/s]
#
# appearance_encoder/config.json: 100% 1.79k/1.79k [00:00<00:00, 10.1MB/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.43G [00:00<?, ?B/s]
#
# temporal_attention.ckpt:   0% 0.00/5.11G [00:00<?, ?B/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/1.45G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.43G [00:00<00:45, 74.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 10.5M/1.45G [00:00<00:21, 67.5MB/s]
#
# temporal_attention.ckpt:   0% 10.5M/5.11G [00:00<01:48, 46.9MB/s]
# diffusion_pytorch_model.safetensors:   1% 31.5M/3.43G [00:00<00:27, 122MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/1.45G [00:00<00:17, 80.0MB/s]
#
# temporal_attention.ckpt:   1% 31.5M/5.11G [00:00<00:53, 94.2MB/s]
# diffusion_pytorch_model.safetensors:   2% 52.4M/3.43G [00:00<00:26, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 41.9M/1.45G [00:00<00:14, 95.6MB/s]
#
# temporal_attention.ckpt:   1% 52.4M/5.11G [00:00<00:50, 101MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 52.4M/1.45G [00:00<00:14, 97.3MB/s]
# diffusion_pytorch_model.safetensors:   2% 73.4M/3.43G [00:00<00:27, 120MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 62.9M/1.45G [00:00<00:14, 93.9MB/s]
#
# temporal_attention.ckpt:   1% 73.4M/5.11G [00:00<00:51, 97.5MB/s]
# diffusion_pytorch_model.safetensors:   3% 94.4M/3.43G [00:00<00:31, 106MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 83.9M/1.45G [00:00<00:13, 98.1MB/s]
#
# temporal_attention.ckpt:   2% 94.4M/5.11G [00:00<00:48, 104MB/s]
# diffusion_pytorch_model.safetensors:   3% 115M/3.43G [00:01<00:32, 101MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 105M/1.45G [00:01<00:13, 103MB/s]
#
# temporal_attention.ckpt:   2% 115M/5.11G [00:01<00:47, 106MB/s]
# diffusion_pytorch_model.safetensors:   4% 136M/3.43G [00:01<00:30, 107MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 126M/1.45G [00:01<00:12, 107MB/s]
#
# temporal_attention.ckpt:   3% 136M/5.11G [00:01<00:46, 106MB/s]
# diffusion_pytorch_model.safetensors:   5% 157M/3.43G [00:01<00:28, 114MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 147M/1.45G [00:01<00:11, 114MB/s]
#
# temporal_attention.ckpt:   3% 157M/5.11G [00:01<00:45, 108MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 168M/1.45G [00:01<00:11, 115MB/s]
# diffusion_pytorch_model.safetensors:   5% 178M/3.43G [00:01<00:30, 105MB/s]
#
# temporal_attention.ckpt:   3% 178M/5.11G [00:01<00:43, 113MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 189M/1.45G [00:01<00:10, 120MB/s]
# diffusion_pytorch_model.safetensors:   6% 199M/3.43G [00:01<00:33, 95.4MB/s]
#
# temporal_attention.ckpt:   4% 199M/5.11G [00:01<00:47, 104MB/s]
# diffusion_pytorch_model.safetensors:   6% 210M/3.43G [00:02<00:35, 91.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 210M/1.45G [00:02<00:12, 99.7MB/s]
#
# temporal_attention.ckpt:   4% 220M/5.11G [00:02<00:50, 96.3MB/s]
# diffusion_pytorch_model.safetensors:   7% 231M/3.43G [00:02<00:33, 95.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  16% 231M/1.45G [00:02<00:12, 94.9MB/s]
#
# temporal_attention.ckpt:   5% 231M/5.11G [00:02<00:53, 91.1MB/s]
# diffusion_pytorch_model.safetensors:   7% 241M/3.43G [00:02<00:35, 89.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 252M/1.45G [00:02<00:12, 99.0MB/s]
# diffusion_pytorch_model.safetensors:   7% 252M/3.43G [00:02<00:38, 82.5MB/s]
#
# temporal_attention.ckpt:   5% 252M/5.11G [00:02<00:52, 91.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 262M/1.45G [00:02<00:13, 89.8MB/s]
#
# temporal_attention.ckpt:   5% 262M/5.11G [00:02<00:51, 93.8MB/s]
# diffusion_pytorch_model.safetensors:   8% 262M/3.43G [00:02<00:39, 81.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 273M/1.45G [00:02<00:12, 91.9MB/s]
# diffusion_pytorch_model.safetensors:   8% 273M/3.43G [00:02<00:39, 79.3MB/s]
#
# temporal_attention.ckpt:   5% 273M/5.11G [00:02<00:55, 87.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 294M/1.45G [00:02<00:11, 98.7MB/s]
# diffusion_pytorch_model.safetensors:   8% 283M/3.43G [00:02<00:41, 76.1MB/s]
#
# temporal_attention.ckpt:   6% 283M/5.11G [00:03<01:01, 78.0MB/s]
# diffusion_pytorch_model.safetensors:   9% 294M/3.43G [00:03<00:38, 82.1MB/s]
#
# temporal_attention.ckpt:   6% 294M/5.11G [00:03<00:58, 82.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 315M/1.45G [00:03<00:11, 97.3MB/s]
# diffusion_pytorch_model.safetensors:   9% 304M/3.43G [00:03<00:38, 81.6MB/s]
#
# temporal_attention.ckpt:   6% 304M/5.11G [00:03<00:58, 81.5MB/s]
# diffusion_pytorch_model.safetensors:   9% 315M/3.43G [00:03<00:36, 84.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 325M/1.45G [00:03<00:12, 86.2MB/s]
#
# temporal_attention.ckpt:   6% 315M/5.11G [00:03<00:58, 81.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 336M/1.45G [00:03<00:13, 85.3MB/s]
#
# temporal_attention.ckpt:   6% 325M/5.11G [00:03<00:58, 81.6MB/s]
# diffusion_pytorch_model.safetensors:  10% 336M/3.43G [00:03<00:35, 87.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 346M/1.45G [00:03<00:13, 84.5MB/s]
#
# temporal_attention.ckpt:   7% 336M/5.11G [00:03<01:00, 78.3MB/s]
# diffusion_pytorch_model.safetensors:  10% 346M/3.43G [00:03<00:35, 87.3MB/s]
# diffusion_pytorch_model.safetensors:  10% 357M/3.43G [00:03<00:34, 89.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  25% 367M/1.45G [00:03<00:12, 86.7MB/s]
# diffusion_pytorch_model.safetensors:  11% 367M/3.43G [00:03<00:35, 86.8MB/s]
#
# temporal_attention.ckpt:   7% 357M/5.11G [00:03<01:01, 77.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 377M/1.45G [00:03<00:12, 83.9MB/s]
# diffusion_pytorch_model.safetensors:  11% 388M/3.43G [00:04<00:30, 101MB/s]
#
# temporal_attention.ckpt:   7% 367M/5.11G [00:04<01:04, 73.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 388M/1.45G [00:04<00:12, 83.2MB/s]
#
# temporal_attention.ckpt:   7% 377M/5.11G [00:04<01:03, 74.0MB/s]
# diffusion_pytorch_model.safetensors:  12% 398M/3.43G [00:04<00:34, 86.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 398M/1.45G [00:04<00:13, 76.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 409M/1.45G [00:04<00:13, 76.9MB/s]
#
# temporal_attention.ckpt:   8% 398M/5.11G [00:04<00:59, 79.1MB/s]
# diffusion_pytorch_model.safetensors:  12% 419M/3.43G [00:04<00:34, 86.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 419M/1.45G [00:04<00:12, 80.8MB/s]
# diffusion_pytorch_model.safetensors:  13% 440M/3.43G [00:04<00:28, 103MB/s]
#
# temporal_attention.ckpt:   8% 419M/5.11G [00:04<00:58, 80.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 430M/1.45G [00:04<00:14, 68.5MB/s]
#
# temporal_attention.ckpt:   8% 430M/5.11G [00:04<00:56, 83.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 440M/1.45G [00:04<00:13, 74.1MB/s]
# diffusion_pytorch_model.safetensors:  13% 461M/3.43G [00:04<00:31, 95.3MB/s]
#
# temporal_attention.ckpt:   9% 440M/5.11G [00:04<00:55, 83.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 451M/1.45G [00:04<00:13, 74.3MB/s]
# diffusion_pytorch_model.safetensors:  14% 472M/3.43G [00:05<00:32, 91.7MB/s]
#
# temporal_attention.ckpt:   9% 451M/5.11G [00:05<00:56, 81.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 461M/1.45G [00:05<00:13, 74.6MB/s]
# diffusion_pytorch_model.safetensors:  14% 482M/3.43G [00:05<00:33, 88.0MB/s]
#
# temporal_attention.ckpt:   9% 461M/5.11G [00:05<00:56, 83.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 472M/1.45G [00:05<00:14, 66.2MB/s]
# diffusion_pytorch_model.safetensors:  14% 493M/3.43G [00:05<00:38, 75.6MB/s]
#
# temporal_attention.ckpt:   9% 472M/5.11G [00:05<00:58, 78.7MB/s]
# diffusion_pytorch_model.safetensors:  15% 503M/3.43G [00:05<00:38, 76.9MB/s]
#
# temporal_attention.ckpt:   9% 482M/5.11G [00:05<00:57, 80.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 493M/1.45G [00:06<00:24, 39.2MB/s]
# diffusion_pytorch_model.safetensors:  15% 514M/3.43G [00:08<03:46, 12.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 503M/1.45G [00:08<01:03, 14.7MB/s]
#
# temporal_attention.ckpt:  10% 493M/5.11G [00:08<06:24, 12.0MB/s]
# diffusion_pytorch_model.safetensors:  15% 524M/3.43G [00:08<02:51, 16.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 514M/1.45G [00:08<00:50, 18.5MB/s]
#
# temporal_attention.ckpt:  10% 503M/5.11G [00:08<04:57, 15.5MB/s]
# diffusion_pytorch_model.safetensors:  16% 535M/3.43G [00:08<02:15, 21.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 524M/1.45G [00:08<00:41, 22.1MB/s]
#
# temporal_attention.ckpt:  10% 514M/5.11G [00:08<04:01, 19.0MB/s]
# diffusion_pytorch_model.safetensors:  16% 545M/3.43G [00:08<01:54, 25.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  37% 535M/1.45G [00:08<00:35, 25.5MB/s]
#
# temporal_attention.ckpt:  10% 524M/5.11G [00:08<03:15, 23.4MB/s]
# diffusion_pytorch_model.safetensors:  16% 556M/3.43G [00:08<01:37, 29.6MB/s]
# diffusion_pytorch_model.safetensors:  17% 566M/3.43G [00:09<01:20, 35.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:
# temporal_attention.ckpt:  38% 1.95G/5.11G [00:24<00:24, 128MB/s]
# diffusion_pytorch_model.safetensors:  58% 2.00G/3.43G [00:25<00:12, 114MB/s]
#
# temporal_attention.ckpt:  39% 1.97G/5.11G [00:25<00:27, 116MB/s]
# diffusion_pytorch_model.safetensors:  59% 2.02G/3.43G [00:25<00:12, 116MB/s]
#
# temporal_attention.ckpt:  39% 1.99G/5.11G [00:25<00:27, 115MB/s]
# diffusion_pytorch_model.safetensors:  60% 2.04G/3.43G [00:25<00:11, 117MB/s]
#
# temporal_attention.ckpt:  39% 2.01G/5.11G [00:25<00:26, 115MB/s]
# diffusion_pytorch_model.safetensors:  60% 2.07G/3.43G [00:25<00:11, 117MB/s]
#
# temporal_attention.ckpt:  40% 2.03G/5.11G [00:25<00:27, 113MB/s]
# diffusion_pytorch_model.safetensors:  61% 2.09G/3.43G [00:25<00:11, 113MB/s]
#
# temporal_attention.ckpt:  40% 2.06G/5.11G [00:27<01:47, 28.3MB/s]
#
# temporal_attention.ckpt:  40% 2.07G/5.11G [00:29<03:11, 15.9MB/s]
#
# temporal_attention.ckpt:  41% 2.10G/5.11G [00:29<01:53, 26.5MB/s]
# diffusion_pytorch_model.safetensors:  61% 2.11G/3.43G [00:29<01:25, 15.4MB/s]
# diffusion_pytorch_model.safetensors:  62% 2.12G/3.43G [00:29<01:12, 18.0MB/s]
#
# temporal_attention.ckpt:  41% 2.12G/5.11G [00:30<01:36, 30.9MB/s]
# diffusion_pytorch_model.safetensors:  62% 2.13G/3.43G [00:30<01:03, 20.5MB/s]
#
# temporal_attention.ckpt:  42% 2.14G/5.11G [00:30<01:12, 40.9MB/s]
# diffusion_pytorch_model.safetensors:  63% 2.15G/3.43G [00:30<00:43, 29.2MB/s]
#
# temporal_attention.ckpt:  42% 2.16G/5.11G [00:30<00:57, 51.0MB/s]
# diffusion_pytorch_model.safetensors:  63% 2.17G/3.43G [00:30<00:32, 38.6MB/s]
#
# temporal_attention.ckpt:  43% 2.18G/5.11G [00:30<00:50, 58.1MB/s]
# diffusion_pytorch_model.safetensors:  64% 2.18G/3.43G [00:30<00:28, 43.2MB/s]
#
# temporal_attention.ckpt:  43% 2.20G/5.11G [00:30<00:40, 71.5MB/s]
# diffusion_pytorch_model.safetensors:  64% 2.20G/3.43G [00:30<00:21, 57.6MB/s]
# diffusion_pytorch_model.safetensors:  65% 2.22G/3.43G [00:30<00:16, 75.1MB/s]
#
# temporal_attention.ckpt:  43% 2.22G/5.11G [00:30<00:35, 81.8MB/s]
# diffusion_pytorch_model.safetensors:  65% 2.24G/3.43G [00:31<00:12, 91.8MB/s]
#
# temporal_attention.ckpt:  44% 2.24G/5.11G [00:31<00:29, 97.5MB/s]
# diffusion_pytorch_model.safetensors:  66% 2.26G/3.43G [00:31<00:11, 105MB/s]
#
# temporal_attention.ckpt:  44% 2.26G/5.11G [00:31<00:27, 105MB/s]
# diffusion_pytorch_model.safetensors:  67% 2.29G/3.43G [00:31<00:09, 119MB/s]
# temporal_attention.ckpt:  51% 2.62G/5.11G [00:33<00:17, 139MB/s]
# diffusion_pytorch_model.safetensors:  77% 2.64G/3.43G [00:34<00:06, 123MB/s]
#
# temporal_attention.ckpt:  52% 2.64G/5.11G [00:34<00:18, 134MB/s]
# diffusion_pytorch_model.safetensors:  78% 2.66G/3.43G [00:34<00:06, 124MB/s]
#
# temporal_attention.ckpt:  52% 2.66G/5.11G [00:34<00:19, 126MB/s]
# diffusion_pytorch_model.safetensors:  78% 2.68G/3.43G [00:34<00:06, 124MB/s]
#
# temporal_attention.ckpt:  53% 2.68G/5.11G [00:34<00:19, 125MB/s]
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.43G [00:34<00:05, 123MB/s]
#
# temporal_attention.ckpt:  53% 2.71G/5.11G [00:34<00:19, 126MB/s]
# diffusion_pytorch_model.safetensors:  80% 2.73G/3.43G [00:34<00:05, 119MB/s]
#
# temporal_attention.ckpt:  53% 2.73G/5.11G [00:34<00:24, 95.9MB/s]
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.43G [00:35<00:07, 94.5MB/s]
# diffusion_pytorch_model.safetensors:  80% 2.76G/3.43G [00:35<00:07, 95.6MB/s]
#
# temporal_attention.ckpt:  54% 2.75G/5.11G [00:35<00:24, 95.9MB/s]
# diffusion_pytorch_model.safetensors:  81% 2.78G/3.43G [00:35<00:05, 110MB/s]
# diffusion_pytorch_model.safetensors:  82% 2.80G/3.43G [00:35<00:05, 114MB/s]
#
# temporal_attention.ckpt:  54% 2.77G/5.11G [00:35<00:24, 93.8MB/s]
#
# temporal_attention.ckpt:  55% 2.79G/5.11G [00:35<00:23, 101MB/s]
# diffusion_pytorch_model.safetensors:  82% 2.82G/3.43G [00:35<00:05, 113MB/s]
#
# temporal_attention.ckpt:  55% 2.81G/5.11G [00:35<00:21, 105MB/s]
# diffusion_pytorch_model.safetensors:  83% 2.84G/3.43G [00:35<00:05, 111MB/s]
#
# temporal_attention.ckpt:  55% 2.83G/5.11G [00:35<00:19, 119MB/s]
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.43G [00:36<00:04, 114MB/s]
#
# temporal_attention.ckpt:  56% 2.85G/5.11G [00:36<00:17, 127MB/s]
# diffusion_pytorch_model.safetensors:  84% 2.88G/3.43G [00:36<00:04, 128MB/s]
#
# temporal_attention.ckpt:  56% 2.87G/5.11G [00:36<00:16, 136MB/s]
# diffusion_pytorch_model.safetensors:  85% 2.90G/3.43G [00:36<00:03, 133MB/s]
#
# temporal_attention.ckpt:  57% 2.89G/5.11G [00:36<00:15, 139MB/s]
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.43G [00:36<00:03, 137MB/s]
#
# temporal_attention.ckpt:  57% 2.92G/5.11G [00:36<00:16, 136MB/s]
# diffusion_pytorch_model.safetensors:  86% 2.95G/3.43G [00:36<00:03, 147MB/s]
#
# temporal_attention.ckpt:  57% 2.94G/5.11G [00:36<00:14, 147MB/s]
# diffusion_pytorch_model.safetensors:  87% 2.97G/3.43G [00:36<00:03, 149MB/s]
#
# temporal_attention.ckpt:  58% 2.96G/5.11G [00:36<00:13, 155MB/s]
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.43G [00:36<00:02, 155MB/s]
#
# temporal_attention.ckpt:  58% 2.98G/5.11G [00:36<00:15, 142MB/s]
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.43G [00:36<00:02, 172MB/s]
#
# temporal_attention.ckpt:  59% 3.00G/5.11G [00:37<00:14, 142MB/s]
# diffusion_pytorch_model.safetensors:  89% 3.04G/3.43G [00:37<00:02, 161MB/s]
#
# temporal_attention.ckpt:  59% 3.02G/5.11G [00:37<00:15, 136MB/s]
# diffusion_pytorch_model.safetensors:  89% 3.06G/3.43G [00:37<00:02, 141MB/s]
#
# temporal_attention.ckpt:  60% 3.04G/5.11G [00:37<00:15, 130MB/s]
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.43G [00:37<00:02, 143MB/s]
#
# temporal_attention.ckpt:  60% 3.06G/5.11G [00:37<00:15, 132MB/s]
# diffusion_pytorch_model.safetensors:  91% 3.10G/3.43G [00:37<00:02, 129MB/s]
#
# temporal_attention.ckpt:  60% 3.08G/5.11G [00:37<00:16, 126MB/s]
# diffusion_pytorch_model.safetensors:  91% 3.12G/3.43G [00:37<00:02, 136MB/s]
# diffusion_pytorch_model.safetensors:  92% 3.15G/3.43G [00:37<00:02, 139MB/s]
#
# temporal_attention.ckpt:  61% 3.10G/5.11G [00:37<00:16, 119MB/s]
# diffusion_pytorch_model.safetensors:  92% 3.17G/3.43G [00:38<00:01, 135MB/s]
#
# temporal_attention.ckpt:  61% 3.12G/5.11G [00:38<00:17, 117MB/s]
# diffusion_pytorch_model.safetensors:  93% 3.19G/3.43G [00:38<00:01, 129MB/s]
#
# temporal_attention.ckpt:  62% 3.15G/5.11G [00:38<00:18, 108MB/s]
# diffusion_pytorch_model.safetensors:  94% 3.21G/3.43G [00:38<00:01, 121MB/s]
#
# temporal_attention.ckpt:  62% 3.17G/5.11G [00:38<00:18, 106MB/s]
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.43G [00:38<00:01, 116MB/s]
#
# temporal_attention.ckpt:  62% 3.19G/5.11G [00:38<00:17, 113MB/s]
# diffusion_pytorch_model.safetensors:  95% 3.25G/3.43G [00:38<00:01, 113MB/s]
#
# temporal_attention.ckpt:  63% 3.21G/5.11G [00:38<00:17, 111MB/s]
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.43G [00:39<00:01, 108MB/s]
#
# temporal_attention.ckpt:  63% 3.23G/5.11G [00:39<00:19, 98.6MB/s]
#
# temporal_attention.ckpt:  63% 3.24G/5.11G [00:39<00:29, 63.4MB/s]
# diffusion_pytorch_model.safetensors:  96% 3.29G/3.43G [00:39<00:01, 68.9MB/s]
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.43G [00:39<00:01, 72.0MB/s]
#
# temporal_attention.ckpt:  64% 3.26G/5.11G [00:39<00:24, 76.8MB/s]
# diffusion_pytorch_model.safetensors:  97% 3.32G/3.43G [00:39<00:01, 85.6MB/s]
#
# temporal_attention.ckpt:  64% 3.28G/5.11G [00:39<00:20, 89.8MB/s]
# diffusion_pytorch_model.safetensors:  98% 3.34G/3.43G [00:40<00:00, 98.9MB/s]
#
# temporal_attention.ckpt:  65% 3.30G/5.11G [00:40<00:17, 103MB/s]
#
# temporal_attention.ckpt:  65% 3.32G/5.11G [00:40<00:17, 103MB/s]
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.43G [00:40<00:00, 94.7MB/s]
#
# temporal_attention.ckpt:  65% 3.34G/5.11G [00:40<00:16, 108MB/s]
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.43G [00:40<00:00, 97.3MB/s]
#
# temporal_attention.ckpt:  66% 3.37G/5.11G [00:40<00:17, 98.1MB/s]
# diffusion_pytorch_model.safetensors:  99% 3.41G/3.43G [00:40<00:00, 93.7MB/s]
# diffusion_pytorch_model.safetensors: 100% 3.42G/3.43G [00:41<00:00, 73.6MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.43G/3.43G [00:41<00:00, 83.3MB/s]
# Fetching 7 files:  57% 4/7 [00:41<00:33, 11.27s/it]
#
# temporal_attention.ckpt:  67% 3.41G/5.11G [00:41<00:17, 95.9MB/s]
#
# temporal_attention.ckpt:  67% 3.43G/5.11G [00:41<00:14, 114MB/s]
#
# temporal_attention.ckpt:  68% 3.46G/5.11G [00:41<00:11, 142MB/s]
#
# temporal_attention.ckpt:  68% 3.48G/5.11G [00:41<00:10, 155MB/s]
#
# temporal_attention.ckpt:  69% 3.51G/5.11G [00:41<00:08, 187MB/s]
#
# temporal_attention.ckpt:  69% 3.54G/5.11G [00:41<00:07, 206MB/s]
#
# temporal_attention.ckpt:  70% 3.58G/5.11G [00:41<00:06, 220MB/s]
#
# temporal_attention.ckpt:  71% 3.61G/5.11G [00:42<00:06, 226MB/s]
#
# temporal_attention.ckpt:  71% 3.64G/5.11G [00:42<00:06, 234MB/s]
#
# temporal_attention.ckpt:  72% 3.67G/5.11G [00:42<00:05, 248MB/s]
#
# temporal_attention.ckpt:  72% 3.70G/5.11G [00:42<00:06, 232MB/s]
#
# temporal_attention.ckpt:  73% 3.73G/5.11G [00:42<00:05, 234MB/s]
#
# temporal_attention.ckpt:  74% 3.76G/5.11G [00:42<00:05, 240MB/s]
#
# temporal_attention.ckpt:  74% 3.80G/5.11G [00:42<00:05, 239MB/s]
#
# temporal_attention.ckpt:  75% 3.83G/5.11G [00:42<00:05, 231MB/s]
#
# temporal_attention.ckpt:  76% 3.86G/5.11G [00:43<00:05, 227MB/s]
#
# temporal_attention.ckpt:  76% 3.89G/5.11G [00:43<00:05, 223MB/s]
#
# temporal_attention.ckpt:  77% 3.92G/5.11G [00:43<00:05, 234MB/s]
#
# temporal_attention.ckpt:  77% 3.95G/5.11G [00:43<00:04, 247MB/s]
#
#
# temporal_attention.ckpt:  99% 5.05G/5.11G [00:47<00:00, 273MB/s]
#
# temporal_attention.ckpt: 100% 5.11G/5.11G [00:48<00:00, 106MB/s]
# Fetching 7 files: 100% 7/7 [00:48<00:00,  6.94s/it]
# Initializing MagicAnimate Pipeline...
# loaded temporal unet's pretrained weights from /content/MagicAnimate-hf/stable-diffusion-v1-5/unet ...
# ### missing keys: 560;
# ### unexpected keys: 0;
# ### Temporal Module Parameters: 417.1376 M
# The config attributes {'addition_embed_type': None, 'addition_embed_type_num_heads': 64, 'addition_time_embed_dim': None, 'conditioning_channels': 3, 'encoder_hid_dim': None, 'encoder_hid_dim_type': None, 'global_pool_conditions': False, 'num_attention_heads': None, 'transformer_layers_per_block': 1} were passed to ControlNetModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# It is recommended to provide `attention_head_dim` when calling `get_down_block`. Defaulting `attention_head_dim` to 8.
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:103: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.21.4",
#   "beta_end": 0.012,
#   "beta_schedule": "linear",
#   "beta_start": 0.00085,
#   "clip_sample": true,
#   "clip_sample_range": 1.0,
#   "dynamic_thresholding_ratio": 0.995,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": true,
#   "steps_offset": 0,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   deprecate("steps_offset!=1", "1.0.0", deprecation_message, standard_warn=False)
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:116: FutureWarning: The configuration file of this scheduler: DDIMScheduler {
#   "_class_name": "DDIMScheduler",
#   "_diffusers_version": "0.21.4",
#   "beta_end": 0.012,
#   "beta_schedule": "linear",
#   "beta_start": 0.00085,
#   "clip_sample": true,
#   "clip_sample_range": 1.0,
#   "dynamic_thresholding_ratio": 0.995,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "rescale_betas_zero_snr": false,
#   "sample_max_value": 1.0,
#   "set_alpha_to_one": true,
#   "steps_offset": 1,
#   "thresholding": false,
#   "timestep_spacing": "leading",
#   "trained_betas": null
# }
#  has not set the configuration `clip_sample`. `clip_sample` should be set to False in the configuration file. Please make sure to update the config accordingly as not setting `clip_sample` in the config might lead to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
#   deprecate("clip_sample not set", "1.0.0", deprecation_message, standard_warn=False)
# Initialization Done!
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://6053ab13ed1afaa2e1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 25/25 [04:45<00:00, 11.42s/it]
# 100% 112/112 [00:06<00:00, 17.57it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x5ee4400] Warning: data is not aligned! This can lead to a speed loss
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 25/25 [01:55<00:00,  4.63s/it]
# 100% 48/48 [00:02<00:00, 18.22it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x5c0c400] Warning: data is not aligned! This can lead to a speed loss
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 25/25 [04:45<00:00, 11.41s/it]
# 100% 112/112 [00:06<00:00, 17.59it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x6b06400] Warning: data is not aligned! This can lead to a speed loss
# /content/MagicAnimate-hf/magicanimate/pipelines/pipeline_animation.py:624: FutureWarning: Accessing config attribute `in_channels` directly via 'UNet3DConditionModel' object attribute is deprecated. Please access 'in_channels' over 'UNet3DConditionModel's config object instead, e.g. 'unet.config.in_channels'.
#   num_channels_latents = self.unet.in_channels
# 100% 30/30 [06:17<00:00, 12.59s/it]
# 100% 128/128 [00:07<00:00, 17.53it/s]
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (1544, 516) to (1552, 528) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x6988400] Warning: data is not aligned! This can lead to a speed loss
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2194, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/MagicAnimate-hf/app.py", line 104, in <module>
#     demo.launch(share=True)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2101, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2198, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 75, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://6053ab13ed1afaa2e1.gradio.live
